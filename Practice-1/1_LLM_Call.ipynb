# %% [markdown]
# # LLM CALL

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage

client = ChatGoogleGenerativeAI(
    model="gemini-flash-latest",
    google_api_key=os.getenv("GOOGLE_API_KEY")
)

response = client.invoke([
    HumanMessage(content="Tell me a sports fact.")
])

print(response.content)
# Out:
# The longest professional baseball game ever played took place in 1981 between the Pawtucket Red Sox and the Rochester Red Wings, lasting a staggering **33 innings** and taking over **8 hours** to complete (spread across two days).
